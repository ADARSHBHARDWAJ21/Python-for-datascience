# %%
print ('Adarsh bhardwaj')
# Out:
# Adarsh bhardwaj

# %%
print ('hello' , end = " -")
print(' learners')
# Out:
# hello - learners

# %%
print("Adarsh" , "lalit", "anand", "Akansha", "aditya", sep = ' , ' )
# Out:
# Adarsh , lalit , anand , Akansha , aditya

# %% [markdown]
# input function

# %%
user_input = input("enter your name : ")
print("username : ",user_input)
# Out:
# enter your name : Adarsh bhardwaj
# username :  Adarsh bhardwaj

# %% [markdown]
# DATA TYPES - DIFFERNT DATA TYPES IN PYTHON 1) Numbers: int, float, complex number

# %%
X = 10; #INT
Y = 3.14 #FLOAT
Z = 2 + 3J # COMPLEX

# %% [markdown]
# String: Sequence of characters enclosed within ('') or (" ")quotes.
# String is inmutable cant be changed

# %%
user_input = "Adarsh bhardwaj"
print(user_input)
# Out:
# Adarsh bhardwaj

# %%
user_input = "arsh"
print(user_input)
# Out:
# arsh

# %% [markdown]
# Boolean values - either true or false

# %%
print(bool(0))
# Out:
# False

# %%
print(bool(1))
# Out:
# True

# %% [markdown]
# Type conversion

# %%
x = 5
y = float(5)
print(x)
print(y)
# Out:
# 5
# 5.0

# %%
x = 10
y = str(x)
print(x)
print(y)
type(x)
#type(y)
# Out:
# 10
# 10
# int

# %%
is_valid_bool = True # boolean type
is_valid_int = int(is_valid_bool)
print(is_valid_bool)
print(is_valid_int)
type(is_valid_int)
# Out:
# True
# 1
# int

# %% [markdown]
# Operators

# %% [markdown]
# Arithmetic operators

# %%
x = 5
y = 8;
print(x+y)
print(x-y)
print(x*y)
print(x/y)
print(x%y)
print(x**y)
print(x//y)
print(x/y)
# Out:
# 13
# -3
# 40
# 0.625
# 5
# 390625
# 0
# 0.625

# %% [markdown]
# Comaprision operators (<,> <=,>=, ==, !=)

# %%
x = 45
y = 34
print(x==y)
print(x!=y)
print(x>y)
print(x<y)
print(x>=y)
print(x<=y)
# Out:
# False
# True
# True
# False
# True
# False

# %% [markdown]
# Logical operators

# %%
x = 5
y = 7
z =78
print(x==5 and y==7)
print(x==8 or y==7)
print(not(x==7 and y==6))
print(x>y and Y<z)
# Out:
# True
# True
# True
# False

# %% [markdown]
# Bitwise operator

# %%
J = 9
K = 10
print(J & K)
# Out:
# 8
