# %% [markdown]
# DAY 1

# %%
user_input = input("Enter your name: ")
print("The username is:",user_input)
# Out:
# Enter your name: adarsh
# The username is: adarsh

# %%
print("Adarsh bhardwaj" , end = "")
# Out:
# Adarsh bhardwaj

# %%
print("Adarsh" ,  end = " ")
print("bhardwaj")
# Out:
# Adarsh bhardwaj

# %%
print("adarsh" ,"darsh" ,"arsh" ,"ash",  sep = ',')
# Out:
# adarsh,darsh,arsh,ash

# %% [markdown]
# Type conversion

# %%
x = 5
y = float(5)
print(y)
# Out:
# 5.0

# %% [markdown]
# Different types of data

# %%
x = 10 #int
y = 3.14 #float
z = 2+3j #complex

# %%
x = 10
y = str(x)
print(x)
print(y)
type(y)
type(y)
# Out:
# 10
# 10
# str

# %% [markdown]
# String -> Linear datastructure -> A sequence of characters

# %% [markdown]
# operators -> Tools in programing that allow us to perform action like adding 2 nos , comparing the values , or assigning the value to a given variable
# 1) Arithmetic operators
# 2)comparison
# 3)Logical
# 4)Bitwise
# 5)Assingment
# 6)Membership
# 7)identity Operators

# %% [markdown]
# Logical operator

# %%
x = 20
print(x<<3)
# Out:
# 160

# %% [markdown]
# DATA STRUCTURES

# %% [markdown]
# STRINGDS

# %%
str1 = 'HElloworld'
print(str1)
first_char = str1[0]
second_char = str1[1]
last_char = str1[-1]
# Out:
# HEllo world

# %%
print(first_char)
print(second_char)
print(last_char)
# Out:
# H
# E
# d

# %% [markdown]
# Slicing

# %%
str1[1:5]
# Out:
# 'Ello'

# %%
str1[7:1]
# Out:
# ''

# %%
str1[:5]
# Out:
# 'HEllo'

# %%
str1[-4:]
# Out:
# 'orld'

# %%
str1[1:10:2]
# Out:
# 'El ol'

# %% [markdown]
# Common strings method and operation

# %% [markdown]
# Upper(), lower()

# %%
String = "Hello world"
String_Upper = String.upper()
print(String_Upper)
# Out:
# HELLO WORLD

# %%
Str1 = "HELLO ADARSH"
Str1_lower = String.lower()
print(Str1_lower)
# Out:
# hello world

# %% [markdown]
# Concatenation

# %%
Str1 = "Hello"
Str2 = "world"
result = Str1 + " " + Str2
print(result)
# Out:
# Hello world

# %% [markdown]
# Replicating string

# %%
Str1 = "abc"
result = Str1 * 3
print(result)
# Out:
# abcabcabc

# %% [markdown]
# comparision of string

# %%
str1 = "Apple"
str2 = "Banana"
print(str1 == str2)
# Out:
# False

# %% [markdown]
# function

# %%
def is_prime(n):
# write your own logic to determine given number n is prime or not

n = int('Enter your number to verify whether it is a prime number or not: ')
result = is_prime(n)

if result:
  print(f'The number {n} is a prime number')
else:
  print(f'The number {n} is not a prime number')
# Out:
#   File "/tmp/ipykernel_6166/1399237199.py", line 1
#     def is_prime(n)
#                    ^
# SyntaxError: expected ':'
