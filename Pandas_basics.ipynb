# %% [markdown]
# installation of pandas

# %%
pip install pandas

# %% [markdown]
# Import the required module

# %% [markdown]
# #Customized indexes

# %%
import pandas as pd

# %%
series_scalar = pd.Series(10 , index=['a','b','c','d','e','f'])
print(series_scalar)
# Out:
# a    10
# b    10
# c    10
# d    10
# e    10
# f    10
# dtype: int64

# %% [markdown]
# #Default indexes
#
# ```
# # This is formatted as code
# ```

# %%
data = [10,20,30,40,50]
series_list = pd.Series(data)
print(series_list)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
type(series_list)
# Out:
# pandas.core.series.Series

# %% [markdown]
# #Load dataset

# %%
customers_df = pd.read_excel('/content/customers.xlsx')
products_df = pd.read_excel('/content/products.xlsx')
purchases_df = pd.read_excel('/content/purchases.xlsx')

# %%
#displays the top 5 records in a customer data frame
customers_df.head()
# Out:
#    id first_name   last_name                      email  gender  street_num  \
# 0   1     Romain   Southcott  rsouthcott0@clickbank.net    Male         1.0
# 1   2     Cosimo   Molyneaux      cmolyneaux1@wiley.com    Male         NaN
# 2   3      Bambi     Westrip     bwestrip2@symantec.com  Female      4057.0
# 3   4     Roarke  Pankettman     rpankettman3@wiley.com    Male        74.0
# 4   5    Mikaela    Althorpe           malthorpe4@51.la     NaN         NaN
#
#   street_name street_suffix         city       state  postcode
# 0   Trailsway          Road    San Diego  California   92127.0
# 1         NaN           NaN      El Paso       Texas       NaN
# 2    Arkansas        Circle  San Antonio       Texas   78220.0
# 3        Debs         Point      Memphis   Tennessee   38150.0
# 4         2nd         Drive          NaN         NaN   83732.0

# %% [markdown]
# #Attributes in series

# %%
series_list
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
data = ['New delhi', 'WashingtonDC', 'London','Paris']
index = ['India', 'USA','UK','France']
series_capital_country = pd.Series(data, index = index)
series_capital_country
# Out:
# India        New delhi
# USA       WashingtonDC
# UK              London
# France           Paris
# dtype: object

# %%
type(series_capital_country)
# Out:
# pandas.core.series.Series

# %%
series_capital_country.index
# Out:
# Index(['India', 'USA', 'UK', 'France'], dtype='object')

# %%
series_capital_country.values
# Out:
# array(['New delhi', 'WashingtonDC', 'London', 'Paris'], dtype=object)

# %%
series_capital_country.dtype
# Out:
# dtype('O')

# %%
series_capital_country.shape
# Out:
# (4,)

# %%
series_capital_country.ndim
# Out:
# 1

# %%
series_capital_country.is_unique
# Out:
# True

# %% [markdown]
# #METHODS IN SERIES --

# %%
marks = [85, 90, 78, 92 , 88]
students = ['gopal','Aashish' ,'Adarsh', 'Akansha','Khushboo']
series_students_marks = pd.Series(marks, index = students)
print(series_students_marks)
# Out:
# gopal       85
# Aashish     90
# Adarsh      78
# Akansha     92
# Khushboo    88
# dtype: int64

# %% [markdown]
# DISPLAY TOP 2 RECORDS IN THE SERIES

# %%
series_students_marks.head(2)
# Out:
# gopal      85
# Aashish    90
# dtype: int64

# %%
#display the bottom 2 records in the series
series_students_marks.tail(2)
# Out:
# Akansha     92
# Khushboo    88
# dtype: int64

# %% [markdown]
# Summary of the descreptive stats

# %%
series_students_marks.describe()
# Out:
# count     5.000000
# mean     86.600000
# std       5.458938
# min      78.000000
# 25%      85.000000
# 50%      88.000000
# 75%      90.000000
# max      92.000000
# dtype: float64

# %% [markdown]
# value_counts() ->returns a series containing the count of unique values

# %%
series_students_marks.value_counts()
# Out:
# 85    1
# 90    1
# 78    1
# 92    1
# 88    1
# Name: count, dtype: int64

# %%
#sort_values()
series_students_marks.sort_values()
# Out:
# Adarsh      78
# gopal       85
# Khushboo    88
# Aashish     90
# Akansha     92
# dtype: int64

# %%
series_students_marks.sort_values(ascending = False) #gives desending values
# Out:
# Akansha     92
# Aashish     90
# Khushboo    88
# gopal       85
# Adarsh      78
# dtype: int64

# %%
# drop() - removes the specified index or column from the series/data frame
series_students_marks.drop('gopal', inplace=True)
print(series_students_marks)
# Out:
# Aashish     90
# Adarsh      78
# Akansha     92
# Khushboo    88
# dtype: int64

# %%
series_students_marks
# Out:
# Aashish     90
# Adarsh      78
# Akansha     92
# Khushboo    88
# dtype: int64

# %%
series_v1 = series_students_marks.drop('gopal') # in this case orignal data structure is not changed changes are made in new data structure series_v1

# %% [markdown]
# MISSING VALUES IN SERIES
#
# ---

# %%
#HOW MANY MISSING VALUES ARE THERE IN DATA FRAME
missing_count = customers_df.isnull().sum()
print(missing_count)
# Out:
# id                 0
# first_name         0
# last_name          0
# email            122
# gender            43
# street_num       262
# street_name       37
# street_suffix     37
# city              79
# state             80
# postcode         157
# dtype: int64

# %% [markdown]
# #Mathematical Operations in Series
# Nan = not a number is a special floating -point value used to represent missing or undefined data in a dataset

# %%
series_1 = pd.Series([1,2,3,4,5] , index = ['a','b','c','d','e'])
series_2 = pd.Series([10,20,-30,40,-50] , index = ['z','y','a', 'c', 'e'])
print(series_1)
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
print(series_2)
# Out:
# z    10
# y    20
# a   -30
# c    40
# e   -50
# dtype: int64

# %%
result_addition = series_1 + series_2
print(result_addition)
# Out:
# a   -29.0
# b     NaN
# c    43.0
# d     NaN
# e   -45.0
# y     NaN
# z     NaN
# dtype: float64

# %%
arr3 = np.array([1,2,3,4,5])
arr4 = np.array([4,5,7,9])
result = arr3 + arr4
print(result)
#in case of numpy arrays it will show error but in case of series it will show Nan
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_4187/667486407.py in <cell line: 0>()
#       1 arr3 = np.array([1,2,3,4,5])
#       2 arr4 = np.array([4,5,7,9])
# ----> 3 result = arr3 + arr4
#       4 print(result)
#       5 #in case of numpy arrays it will show error but in case of series it will show Nan
#
# ValueError: operands could not be broadcast together with shapes (5,) (4,)

# %%
#Data imputation - filling Nan values with '0' or mean or median is called Data imputation
#if the percentage of nan value is very less then in that case we drop all nan values

# %%
result = result_addition.fillna(0)
print(result)
# Out:
# a   -29.0
# b     0.0
# c    43.0
# d     0.0
# e   -45.0
# y     0.0
# z     0.0
# dtype: float64

# %%
#drop all missing values
result_addition_dropped = result_addition.dropna()
print(result_addition_dropped)
# Out:
# a   -29.0
# c    43.0
# e   -45.0
# dtype: float64

# %%
#Multiplication of two Series
result_multiplication = series_1 * series_2
print(result_multiplication)
# Out:
# a    -30.0
# b      NaN
# c    120.0
# d      NaN
# e   -250.0
# y      NaN
# z      NaN
# dtype: float64

# %%
#division of 2 series
result_division = series_1 / series_2
print(result_division)
# Out:
# a   -0.033333
# b         NaN
# c    0.075000
# d         NaN
# e   -0.100000
# y         NaN
# z         NaN
# dtype: float64

# %% [markdown]
# #DATA FRAME

# %%
purchases_df.head()
# Out:
#    Unnamed: 0  id           purch_date  customer_num  product_num  amount  \
# 0           0   1  2019-01-03 00:00:00           823           27      12
# 1           1   2  2019-01-03 00:00:00           606           28      14
# 2           2   3  2019-01-03 00:00:00           955            9      17
# 3           3   4  2019-01-03 00:00:00           577           19       3
# 4           4   5  2019-01-03 00:00:00           429            8      18
#
#       paid
# 0  $568.92
# 1  $395.36
# 2  $510.17
# 3   $68.49
# 4  $759.42

# %%
customers_df.head()
# Out:
#    id first_name   last_name                      email  gender  street_num  \
# 0   1     Romain   Southcott  rsouthcott0@clickbank.net    Male         1.0
# 1   2     Cosimo   Molyneaux      cmolyneaux1@wiley.com    Male         NaN
# 2   3      Bambi     Westrip     bwestrip2@symantec.com  Female      4057.0
# 3   4     Roarke  Pankettman     rpankettman3@wiley.com    Male        74.0
# 4   5    Mikaela    Althorpe           malthorpe4@51.la     NaN         NaN
#
#   street_name street_suffix         city       state  postcode
# 0   Trailsway          Road    San Diego  California   92127.0
# 1         NaN           NaN      El Paso       Texas       NaN
# 2    Arkansas        Circle  San Antonio       Texas   78220.0
# 3        Debs         Point      Memphis   Tennessee   38150.0
# 4         2nd         Drive          NaN         NaN   83732.0

# %%
# drop the column named 'Unnamed: 0' from the above products_df and purchases_df data frame
purchases_df.drop(columns=['Unnamed: 0'], errors='ignore', inplace=True)
products_df.drop(columns=['Unnamed: 0'], errors='ignore', inplace=True)

# %%
purchases_df.head()
# Out:
#    id           purch_date  customer_num  product_num  amount     paid
# 0   1  2019-01-03 00:00:00           823           27      12  $568.92
# 1   2  2019-01-03 00:00:00           606           28      14  $395.36
# 2   3  2019-01-03 00:00:00           955            9      17  $510.17
# 3   4  2019-01-03 00:00:00           577           19       3   $68.49
# 4   5  2019-01-03 00:00:00           429            8      18  $759.42

# %%
products_df.head()
# Out:
#    id                           product    cost   company
# 0   1              Liners - Baking Cups   $6.36  Skipfire
# 1   2        Nori Sea Weed - Gold Label  $85.74   Dynazzy
# 2   3                Bar Bran Honey Nut  $65.40      Ntag
# 3   4        Soup - Campbells Beef Stew  $68.16  Photojam
# 4   5  Wine - Shiraz Wolf Blass Premium  $87.39      Eare

# %%
#iloc vs loc
customers_df.shape
# Out:
# (1000, 11)

# %%
customers_df.iloc[4:11, 1:3] #iloc is used for default indexing
# Out:
#     first_name   last_name
# 4      Mikaela    Althorpe
# 5    Magdalena      Cullip
# 6     Marietta      Heball
# 7         Tine   McSperrin
# 8   Enrichetta  de Villier
# 9         Sari     Poulden
# 10      Natale     Martina

# %%
customers_df.loc[4:11, ['first_name','' ]]
# Out:
# 4        Mikaela
# 5      Magdalena
# 6       Marietta
# 7           Tine
# 8     Enrichetta
# 9           Sari
# 10        Natale
# 11          Noni
# Name: first_name, dtype: object

# %% [markdown]
# #Two ways to access the subset of a given data frame

# %%
#filtering purpose
male_customers = customers_df[customers_df['gender'] == 'Male']
print(male_customers)
# Out:
#        id first_name    last_name                           email gender  \
# 0       1     Romain    Southcott       rsouthcott0@clickbank.net   Male
# 1       2     Cosimo    Molyneaux           cmolyneaux1@wiley.com   Male
# 3       4     Roarke   Pankettman          rpankettman3@wiley.com   Male
# 10     11     Natale      Martina         nmartinaa@wordpress.com   Male
# 12     13      Mikol      MacWhan             mmacwhanc@patch.com   Male
# ..    ...        ...          ...                             ...    ...
# 984   985     Tailor      Sealeaf              tsealeafrc@irs.gov   Male
# 986   987       Eric    Mountford       emountfordre@blogspot.com   Male
# 997   998      Tobit         Birt                             NaN   Male
# 998   999     Issiah  Standbrooke  istandbrookerq@yellowpages.com   Male
# 999  1000     Elmore       Malpas                             NaN   Male
#
#      street_num   street_name street_suffix       city           state  \
# ...

# %%
male_customers
# Out:
#        id first_name    last_name                           email gender  \
# 0       1     Romain    Southcott       rsouthcott0@clickbank.net   Male
# 1       2     Cosimo    Molyneaux           cmolyneaux1@wiley.com   Male
# 3       4     Roarke   Pankettman          rpankettman3@wiley.com   Male
# 10     11     Natale      Martina         nmartinaa@wordpress.com   Male
# 12     13      Mikol      MacWhan             mmacwhanc@patch.com   Male
# ..    ...        ...          ...                             ...    ...
# 984   985     Tailor      Sealeaf              tsealeafrc@irs.gov   Male
# 986   987       Eric    Mountford       emountfordre@blogspot.com   Male
# 997   998      Tobit         Birt                             NaN   Male
# 998   999     Issiah  Standbrooke  istandbrookerq@yellowpages.com   Male
# 999  1000     Elmore       Malpas                             NaN   Male
#
#      street_num   street_name street_suffix       city           state  \
# ...

# %%
purchases_df.head()
# Out:
#    id           purch_date  customer_num  product_num  amount     paid
# 0   1  2019-01-03 00:00:00           823           27      12  $568.92
# 1   2  2019-01-03 00:00:00           606           28      14  $395.36
# 2   3  2019-01-03 00:00:00           955            9      17  $510.17
# 3   4  2019-01-03 00:00:00           577           19       3   $68.49
# 4   5  2019-01-03 00:00:00           429            8      18  $759.42

# %% [markdown]
# Acess only 2, 3 ,4th row also only 'product_num' and 'paid' column

# %%
purchases_df.loc[2:4, ['product_num', 'paid']]
# Out:
#    product_num     paid
# 2            9  $510.17
# 3           19   $68.49
# 4            8  $759.42

# %%
purchases_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6000 entries, 0 to 5999
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            6000 non-null   int64
#  1   purch_date    6000 non-null   object
#  2   customer_num  6000 non-null   int64
#  3   product_num   6000 non-null   int64
#  4   amount        6000 non-null   int64
#  5   paid          6000 non-null   object
# dtypes: int64(4), object(2)
# memory usage: 281.4+ KB

# %%
#renaming row label of a dataframe

# %%
customers_df.head()
# Out:
#    id first_name   last_name                      email  gender  street_num  \
# 0   1     Romain   Southcott  rsouthcott0@clickbank.net    Male         1.0
# 1   2     Cosimo   Molyneaux      cmolyneaux1@wiley.com    Male         NaN
# 2   3      Bambi     Westrip     bwestrip2@symantec.com  Female      4057.0
# 3   4     Roarke  Pankettman     rpankettman3@wiley.com    Male        74.0
# 4   5    Mikaela    Althorpe           malthorpe4@51.la     NaN         NaN
#
#   street_name street_suffix         city       state  postcode
# 0   Trailsway          Road    San Diego  California   92127.0
# 1         NaN           NaN      El Paso       Texas       NaN
# 2    Arkansas        Circle  San Antonio       Texas   78220.0
# 3        Debs         Point      Memphis   Tennessee   38150.0
# 4         2nd         Drive          NaN         NaN   83732.0

# %%
customers_df.rename(index = {0: 'first_customoer'}, inplace=True)
customers_df
# Out:
#                    id first_name    last_name                           email  \
# first_customoer     1     Romain    Southcott       rsouthcott0@clickbank.net
# 1                   2     Cosimo    Molyneaux           cmolyneaux1@wiley.com
# 2                   3      Bambi      Westrip          bwestrip2@symantec.com
# 3                   4     Roarke   Pankettman          rpankettman3@wiley.com
# 4                   5    Mikaela     Althorpe                malthorpe4@51.la
# ...               ...        ...          ...                             ...
# 995               996    Merrili        Alman            malmanrn@cornell.edu
# 996               997    Winonah       Heckle               whecklero@fc2.com
# 997               998      Tobit         Birt                             NaN
# 998               999     Issiah  Standbrooke  istandbrookerq@yellowpages.com
# 999              1000     Elmore       Malpas                             NaN
#
# ...

# %%
customers_df.rename(columns={'street_name': 'street_address'}, inplace=True)
customers_df.head()
# Out:
#                  id first_name   last_name                      email  gender  \
# first_customoer   1     Romain   Southcott  rsouthcott0@clickbank.net    Male
# 1                 2     Cosimo   Molyneaux      cmolyneaux1@wiley.com    Male
# 2                 3      Bambi     Westrip     bwestrip2@symantec.com  Female
# 3                 4     Roarke  Pankettman     rpankettman3@wiley.com    Male
# 4                 5    Mikaela    Althorpe           malthorpe4@51.la     NaN
#
#                  street_num street_address street_suffix         city  \
# first_customoer         1.0      Trailsway          Road    San Diego
# 1                       NaN            NaN           NaN      El Paso
# 2                    4057.0       Arkansas        Circle  San Antonio
# 3                      74.0           Debs         Point      Memphis
# 4                       NaN            2nd         Drive          NaN
#
#                       state  postcode
# ...

# %% [markdown]
# Finding the unique value

# %%
unique_gender = customers_df['gender'].unique()
print(unique_gender)
# Out:
# ['Male' 'Female' nan]

# %% [markdown]
# #count of no of unique values

# %%
unique_gender_count = customers_df['gender'].nunique()
print(unique_gender_count)
# Out:
# 2
