# %%
x = 10
if x > 0:
  print('x is positive')
# Out:
# x is positive

# %%
x = -10
if  x > 0:
  print('x is positive')

# %% [markdown]
# Take care of indentation error by providing the appropriate spacing

# %%
x = -5
if x > 0:
  # this line is a part of the if block
  print('x is positive')

  # this line is outside the if block
print('Hello World')
# Out:
# Hello World

# %%
x = 6

# %% [markdown]
# write a code to input the number from the user and check whether the number is a multiple of 2 or not

# %%
num = int(input("Enter a number: "))
if num % 2 == 0:
   print('The number is multiple of 2(Even number)')
else:
   print('The number is Not a multiple of 2 (odd number)')
# Out:
# Enter a number: 1
# The number is Not a multiple of 2 (odd number)

# %% [markdown]
# #problem 1

# %%
dict1 = {'a':1, 'b':2, 'c':3}
keys_to_check = 'b'
# write  a code to check if the ket exists in the dictionary or not
if keys_to_check in dict1:
  print('yes')
else:
  print('no')
# Out:
# yes

# %% [markdown]
# if-elif-else statement

# %%
x = 10
if x > 10:
  print('x is greater then 10')
elif x == 10:
   print('x is equals to 10')
else:
   print('x is less then 10')
# Out:
# x is equals to 10

# %%
x = 20
if x > 10:
  print('x is greater then 10')
elif x == 10:
  print('x is equals to 10')
else:
  print(' x is smaller then 10')
# Out:
# x is greater then 10

# %% [markdown]
# Nested conditional statements

# %%
x = -10
y = 5
if x>0:
  print('x is greater then 0')
  if y>0:
    print('y is greater then 0')
    print('both x and y are positive')
  else:
      print('y is negative')
      print('x is positive and y is negative ')

else:
  print('x is negative')
# Out:
# x is negative

# %% [markdown]
# Loops

# %%
fruits = ['apple', 'banana', 'cherry']
for fruit in fruits:
  print(fruit)
# Out:
# apple
# banana
# cherry
